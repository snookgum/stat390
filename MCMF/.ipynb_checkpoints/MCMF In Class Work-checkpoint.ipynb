# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimpy import clean_columns
import geopandas as gpd
from shapely.geometry import MultiPolygon

# %%
df = pd.read_csv('My_CHI._My_Future._Programs.csv')

# %%
df = clean_columns(df)
# Out:
# 39 column names have been cleaned

# %%
df.columns
# Out:
# Index(['program_id', 'program_name', 'description', 'org_name',
#        'category_name', 'capacity', 'min_age', 'max_age', 'address', 'city',
#        'state', 'zip_code', 'program_type', 'program_url', 'online_address',
#        'registration_url', 'registration_open', 'registration_deadline',
#        'start_date', 'end_date', 'start_time', 'end_time', 'contact_name',
#        'contact_email', 'contact_phone', 'program_price',
#        'geographic_cluster_name', 'scholarship_available', 'participants_paid',
#        'transport_provided', 'has_free_food', 'meeting_type', 'image',
#        'hidden_programs', 'featured', 'tag', 'latitude', 'longitude',
#        'location'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    program_id                                       program_name  \
# 0      138124  How to Finally Get Consistent with Healthy Eating
#
#                                          description                org_name  \
# 0  During this workshop youÕll identify the main ...  Chicago Public Library
#
#       category_name  capacity  min_age  max_age address city  ...  \
# 0  Academic Support       NaN       13       99     NaN  NaN  ...
#
#   transport_provided  has_free_food meeting_type image hidden_programs  \
# 0              False          False       online   NaN           False
#
#   featured    tag latitude longitude location
# 0    False  Event      NaN       NaN      NaN
#
# [1 rows x 39 columns]

# %%
df.program_name
# Out:
# 0        How to Finally Get Consistent with Healthy Eating
# 1                   English Conversation with Chicago Lawn
# 2        Law at the Library: Changes in Tax Law, Know B...
# 3               Voices for Justice: Author Qian Julie Wang
# 4        Science Fiction & Fantasy Book Group: Dawn by ...
#                                ...
# 68591                Tumbling Lev. 4 - 6 at Morgan Park SC
# 68592    Ice Skating - Freestyle Ice Basic1-FS6 at Morg...
# 68593     Ice Skating - Adult Open Skate at Morgan Park SC
# 68594                       Stick & Puck at Morgan Park SC
# 68595              Ice Skating - Basic 1 at Morgan Park SC
# Name: program_name, Length: 68596, dtype: object

# %% [markdown]
# ## Splitting Data

# %% [markdown]
# ### Meeting Type

# %%
df_online = df[df['meeting_type'] == 'online']

# %%
df_face = df[df['meeting_type'] == 'face_to_face']

# %%
df_face.head(1)
# Out:
#      program_id                                    program_name  \
# 135      106198  All CPL Locations Closed Thursday, November 25
#
#                                            description  \
# 135  All CPL locations will be closed Thursday, Nov...
#
#                    org_name            category_name  capacity  min_age  \
# 135  Chicago Public Library  Helping Your Community.      99.0        0
#
#      max_age address     city  ... transport_provided  has_free_food  \
# 135       99     NaN  Chicago  ...              False          False
#
#      meeting_type image hidden_programs featured    tag latitude longitude  \
# 135  face_to_face   NaN           False    False  Event      NaN       NaN
#
#     location
# 135      NaN
#
# [1 rows x 39 columns]

# %%
df_face.transport_provided.value_counts()
# Out:
# False    61234
# True        69
# Name: transport_provided, dtype: int64

# %%
# dataframe of in person programs where transportation is provided
df_tp_og_index = df[df['transport_provided'] == True]

# %%
# reindexing df_tp_og_index for ease of use when working with rows where transportation is provided
df_tp = df_tp_og_index.reset_index()

# %%
#dropping old index
df_tp = df_tp.iloc[: , 1:]

# %%
df_tp
# Out:
#     program_id                                       program_name  \
# 0       121076                           Test Program 4/21/2022-4
# 1        98698               Kayak and Caring for the Environment
# 2       124453                             Cannabis Legal Studies
# 3        98700               Kayak and Caring for the Environment
# 4       127088                                         Chicago200
# ..         ...                                                ...
# 66      134605                   Christ, Camping, & Coming of Age
# 67      134606                   Christ, Camping, & Coming of Age
# 68      134605                   Christ, Camping, & Coming of Age
# 69       94257  MAPSCorps @ Centers for New Horizons - Altgeld...
# 70       94257  MAPSCorps @ Centers for New Horizons - Altgeld...
#
#                                           description                org_name  \
# 0                          <p>Test for no address</p>                DYN Tech
# 1   <p>Time: 9:30 a.m. - 2:30 p.m.<br>Capacity: 15...  John G. Shedd Aquarium
# 2   <p><strong>Program Overview</strong></p><p>Leg...       LAW AND THE FAM ℠
# 3   <p>Dates: Please only select one of three date...  John G. Shedd Aquarium
# 4   <p>Chicago200 is an annual leadership program ...          Common Purpose
# ..                                                ...                     ...
# 66  <p>Two safe, fun-filled, and spiritually nurtu...            Agape Center
# 67  <p>Two safe, fun-filled, and spiritually nurtu...            Agape Center
# 68  <p>Two safe, fun-filled, and spiritually nurtu...            Agape Center
# 69  <p>Are you ready to build skills for your futu...               MAPSCorps
# 70  <p>Are you ready to build skills for your futu...               MAPSCorps
#
#               category_name  capacity  min_age  max_age  \
# 0            Transportation       NaN        4       21
# 1                   Science      15.0       13       18
# 2             Work + Career      25.0       18       25
# 3                   Nature.      15.0       13       18
# 4   Helping Your Community.       NaN       18       25
# ..                      ...       ...      ...      ...
# 66                  Nature.      12.0       11       14
# 67       Sports + Wellness.      12.0       11       14
# 68       Sports + Wellness.      12.0       11       14
# 69            Work + Career      10.0       16       19
# 70                  Science      10.0       16       19
#
#                          address            city  ... transport_provided  \
# 0          1234 East 56th Street         Chicago  ...               True
# 1                            NaN             NaN  ...               True
# 2                            NaN             NaN  ...               True
# 3                            NaN             NaN  ...               True
# 4                            NaN         Chicago  ...               True
# ..                           ...             ...  ...                ...
# 66                9600 Wolf Road  Willow Springs  ...               True
# 67                9600 Wolf Road  Willow Springs  ...               True
# 68                9600 Wolf Road  Willow Springs  ...               True
# 69  13107 South Ingleside Avenue         Chicago  ...               True
# 70  13107 South Ingleside Avenue         Chicago  ...               True
#
#     has_free_food  meeting_type  \
# 0            True  face_to_face
# 1           False  face_to_face
# 2            True        online
# 3           False  face_to_face
# 4            True  face_to_face
# ..            ...           ...
# 66           True  face_to_face
# 67           True  face_to_face
# 68           True  face_to_face
# 69          False  face_to_face
# 70          False  face_to_face
#
#                                                 image hidden_programs  \
# 0   https://cityoflearning-uploads.s3.amazonaws.co...           False
# 1   https://cityoflearning-uploads.s3.amazonaws.co...           False
# 2   https://cityoflearning-uploads.s3.amazonaws.co...           False
# 3   https://cityoflearning-uploads.s3.amazonaws.co...           False
# 4   https://cityoflearning-uploads.s3.amazonaws.co...           False
# ..                                                ...             ...
# 66  https://cityoflearning-uploads.s3.amazonaws.co...           False
# 67  https://cityoflearning-uploads.s3.amazonaws.co...           False
# 68  https://cityoflearning-uploads.s3.amazonaws.co...           False
# 69  https://cityoflearning-uploads.s3.amazonaws.co...           False
# 70  https://cityoflearning-uploads.s3.amazonaws.co...           False
#
#    featured      tag   latitude  longitude                            location
# 0     False  Program  41.793495 -87.595184  POINT (-87.595184326 41.793495178)
# 1     False    Event        NaN        NaN                                 NaN
# 2     False      Job        NaN        NaN                                 NaN
# 3     False    Event        NaN        NaN                                 NaN
# 4     False    Event        NaN        NaN                                 NaN
# ..      ...      ...        ...        ...                                 ...
# 66    False    Event  41.713299 -87.895203  POINT (-87.895202637 41.713298798)
# 67    False    Event  41.713310 -87.895157   POINT (-87.89515686 41.713310242)
# 68    False    Event  41.713299 -87.895203  POINT (-87.895202637 41.713298798)
# 69    False      Job  41.657211 -87.599350  POINT (-87.599349976 41.657211304)
# 70    False  Program  41.657211 -87.599350  POINT (-87.599349976 41.657211304)
#
# [71 rows x 39 columns]

# %%
# there was 1 row value in the category_name column called "Computers" and 777 called "Computers." - replacing "Computer with "Computers.
df["category_name"] = df["category_name"].replace("Computers", "Computers.")

# %%
# 1 row value with Science + Math, split into two 
# Duplicate 
new_row = df.loc[df['category_name'] == 'Science & Math'].copy()

# Append new row
df = df.append(new_row, ignore_index=True)
# Out:
# /var/folders/8n/jcf8jkgd07q33yx5hgq1969r0000gn/T/ipykernel_40652/52338994.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)

# %%
df['program_id'].loc[df['category_name'] == 'Science & Math']
# Out:
# 7942     76728
# 68596    76728
# Name: program_id, dtype: int64

# %%
df.loc[7942, 'category_name'] = 'Science'
df.loc[68597, 'category_name'] = 'Math'

# %%
df.category_name.value_counts()
# Out:
# Sports + Wellness.          35310
# Music & Art.                17274
# Reading & Writing.           6830
# Academic Support             2127
# Science                      1311
# Building & Fixing Things     1127
# Computers.                   1014
# Nature.                       698
# Helping Your Community.       523
# Performance.                  493
# Work + Career                 377
# Food.                         376
# Healthcare                    367
# Managing Money.               348
# Digital Media.                169
# Social Studies                162
# Customer/Human Service         39
# Math                           30
# Teaching                       11
# Transportation                  7
# Law                             3
# Science & Math                  1
# Name: category_name, dtype: int64

# %% [markdown]
# Some notes / questions
# 1. For categories, what does the academic support category look like? Can reading & writing, social studies, science, science/math be included in academic support or should they be kept separate?

# %%
df.program_price.value_counts()
# Out:
# Free             33089
# $50 or Less      24873
# More Than $50     7037
# Unknown           3598
# Name: program_price, dtype: int64

# %%
program_price_grouped = df.groupby(['program_price', 'category_name'], dropna = False)

# %%
program_price_grouped.size()
# Out:
# program_price  category_name
# $50 or Less    Academic Support             559
#                Building & Fixing Things     237
#                Computers.                     6
#                Customer/Human Service         2
#                Digital Media.                38
#                                            ...
# Unknown        Music & Art.                  85
#                Nature.                       12
#                Reading & Writing.             2
#                Science                        3
#                Sports + Wellness.          3408
# Length: 61, dtype: int64

# %%
pivot_table = program_price_grouped.size().unstack('category_name')

# %%
pivot_table
# Out:
# category_name  Academic Support  Building & Fixing Things  Computers.  \
# program_price
# $50 or Less               559.0                     237.0         6.0
# Free                      575.0                     706.0       759.0
# More Than $50             611.0                      81.0        13.0
# Unknown                     NaN                      14.0         NaN
#
# category_name  Customer/Human Service  Digital Media.  Food.  Healthcare  \
# program_price
# $50 or Less                       2.0            38.0   43.0        51.0
# Free                             29.0            52.0  287.0       276.0
# More Than $50                     NaN             NaN    NaN        13.0
# Unknown                           NaN             NaN    NaN         NaN
#
# category_name  Helping Your Community.  Law  Managing Money.  ...  Nature.  \
# program_price                                                 ...
# $50 or Less                        5.0  NaN              NaN  ...    222.0
# Free                             384.0  2.0            235.0  ...    388.0
# More Than $50                      6.0  NaN              NaN  ...     30.0
# Unknown                            NaN  NaN              NaN  ...     12.0
#
# category_name  Performance.  Reading & Writing.  Science  Science & Math  \
# program_price
# $50 or Less            95.0               109.0    208.0             NaN
# Free                  258.0              4218.0    816.0             1.0
# More Than $50          77.0                 7.0     17.0             NaN
# Unknown                 NaN                 2.0      3.0             NaN
#
# category_name  Social Studies  Sports + Wellness.  Teaching  Transportation  \
# program_price
# $50 or Less               1.0             18907.0       2.0             1.0
# Free                    115.0              6916.0       3.0             6.0
# More Than $50             NaN              5286.0       1.0             NaN
# Unknown                   NaN              3408.0       NaN             NaN
#
# category_name  Work + Career
# program_price
# $50 or Less              1.0
# Free                   211.0
# More Than $50            4.0
# Unknown                  NaN
#
# [4 rows x 22 columns]

# %% [markdown]
# ### Min Age > 25 should be discarded, Max Age > 25 should be family event

# %%
df_young = df.loc[df['max_age'] <= 25]
df_young = df_young.loc[df_young['min_age'] <= 25]

# %%
df_young.shape
# Out:
# (44867, 39)

# %%
# find the number of unique values in 'program_id'
unique_values = df_young['program_id'].nunique()

# print the result
print(unique_values)
# Out:
# 41033

# %%
df_young.category_name.value_counts()
# Out:
# Sports + Wellness.          22535
# Music & Art.                11396
# Reading & Writing.           5146
# Academic Support             1594
# Science                       841
# Building & Fixing Things      652
# Computers.                    548
# Nature.                       404
# Helping Your Community.       381
# Food.                         328
# Performance.                  300
# Work + Career                 249
# Healthcare                    230
# Digital Media.                120
# Managing Money.                39
# Social Studies                 30
# Customer/Human Service         29
# Math                           28
# Transportation                  7
# Teaching                        5
# Law                             3
# Science & Math                  1
# Name: category_name, dtype: int64

# %% [markdown]
# ## VISUALIZATIONS

# %% [markdown]
# ### Maps

# %%
commareas = pd.read_csv('CommAreas.csv')

# %%
chicago_map = gpd.read_file('chicagomap.shp')
chicago_map['geometry'] = chicago_map['geometry'].apply(lambda x: MultiPolygon([x]) if x.geom_type == 'Polygon' else x)

# %%
commareas['geometry'] = chicago_map['geometry']

# %%
chicagogeo = gpd.GeoDataFrame(commareas, geometry='geometry')

# %% [markdown]
# #########################################

# %%
chicago_activities = gpd.GeoDataFrame(df_young, geometry=gpd.points_from_xy(df_young.longitude, df_young.latitude))
chicago_activities.crs = chicago_map.crs

# Perform the spatial join
joined_data = gpd.sjoin(chicago_map, chicago_activities, how='left', op='intersects')
# Out:
# /Users/ashleywitarsa/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
chicago_activities = gpd.GeoDataFrame(df_young, geometry=gpd.points_from_xy(df_young.longitude, df_young.latitude))
chicago_activities.crs = chicago_map.crs

# Perform the spatial join
joined_data = gpd.sjoin(chicagogeo, chicago_activities, how='left', op='intersects')
# Out:
# /Users/ashleywitarsa/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
from fuzzywuzzy import fuzz, process

def match_column(row, column, options):
    best_match = process.extractOne(row[column], options)
    return best_match[0]

chicagogeo['GEOG'] = chicagogeo.apply(match_column, args=('COMMUNITY', dem['GEOG']), axis=1)

joined = pd.merge(chicagogeo, dem, on='GEOG')
# Out:
#                                              geometry  index_right  \
# 0   MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...      40782.0
# 0   MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...      41703.0
# 0   MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...      43603.0
# 0   MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...      42102.0
# 0   MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...      41939.0
# ..                                                ...          ...
# 76  MULTIPOLYGON (((-87.80676 42.00084, -87.80676 ...      58601.0
# 76  MULTIPOLYGON (((-87.80676 42.00084, -87.80676 ...      57055.0
# 76  MULTIPOLYGON (((-87.80676 42.00084, -87.80676 ...      58938.0
# 76  MULTIPOLYGON (((-87.80676 42.00084, -87.80676 ...      55944.0
# 76  MULTIPOLYGON (((-87.80676 42.00084, -87.80676 ...      58629.0
#
#     program_id                      program_name  \
# 0     123933.0         Bronzeville Youth Shelter
# 0     123927.0              Ignite Belfort House
# 0     123927.0              Ignite Belfort House
# 0     123933.0         Bronzeville Youth Shelter
# 0     107719.0      Bitty Basketball at Anderson
# ..         ...                               ...
# 76    152120.0  Science of Superheroes at Edison
# 76    152756.0              Art & ABCs at Edison
# 76     88777.0         Young Scientist at Online
# 76    153205.0          Little Artists at Edison
# 76    150078.0          Kiddie College at Edison
#
#                                           description               org_name  \
# 0   <p>BYS provides minor youth, ages 14 to 17, wi...                 Ignite
# 0   <p>Located in Chicago’s Bronzeville neighborho...                 Ignite
# 0   <p>Located in Chicago’s Bronzeville neighborho...                 Ignite
# 0   <p>BYS provides minor youth, ages 14 to 17, wi...                 Ignite
# 0   With lowered rims and smaller balls, this inst...  Chicago Park District
# ..                                                ...                    ...
# 76  Every hero has a story.  Children will become ...  Chicago Park District
# 76  Kids will get crafty and participate in activi...  Chicago Park District
# 76  Join Barbara for Young Scientist online!  This...  Chicago Park District
# 76  Involves children learning and experiencing ar...  Chicago Park District
# 76  This recreational based preschool-like activit...  Chicago Park District
#
#               category_name  capacity  min_age  max_age  ...  \
# 0   Helping Your Community.       NaN     14.0     17.0  ...
# 0   Helping Your Community.       NaN     18.0     22.0  ...
# 0   Helping Your Community.       NaN     18.0     22.0  ...
# 0   Helping Your Community.       NaN     14.0     17.0  ...
# 0        Sports + Wellness.      15.0      3.0      6.0  ...
# ..                      ...       ...      ...      ...  ...
# 76             Music & Art.      10.0      3.0      6.0  ...
# 76             Music & Art.      12.0      3.0      6.0  ...
# 76                  Science      20.0      3.0      6.0  ...
# 76             Music & Art.      12.0      3.0      6.0  ...
# 76         Academic Support      10.0      4.0      6.0  ...
#
#    transport_provided has_free_food  meeting_type  \
# 0               False          True  face_to_face
# 0               False          True  face_to_face
# 0               False          True  face_to_face
# 0               False          True  face_to_face
# 0               False         False  face_to_face
# ..                ...           ...           ...
# 76              False         False  face_to_face
# 76              False         False  face_to_face
# 76              False         False        online
# 76              False         False  face_to_face
# 76              False         False  face_to_face
#
#                                                 image hidden_programs  \
# 0   https://cityoflearning-uploads.s3.amazonaws.co...           False
# 0   https://cityoflearning-uploads.s3.amazonaws.co...           False
# 0   https://cityoflearning-uploads.s3.amazonaws.co...           False
# 0   https://cityoflearning-uploads.s3.amazonaws.co...           False
# 0                                                 NaN           False
# ..                                                ...             ...
# 76                                                NaN           False
# 76                                                NaN           False
# 76                                                NaN           False
# 76                                                NaN           False
# 76                                                NaN           False
#
#    featured      tag   latitude  longitude                            location
# 0     False  Program  41.826199 -87.621597   POINT (-87.62159729 41.826198578)
# 0     False  Program  41.826199 -87.621597   POINT (-87.62159729 41.826198578)
# 0     False  Program  41.826199 -87.621597   POINT (-87.62159729 41.826198578)
# 0     False  Program  41.826199 -87.621597   POINT (-87.62159729 41.826198578)
# 0     False  Program  41.826698 -87.620499  POINT (-87.620498657 41.826698303)
# ..      ...      ...        ...        ...                                 ...
# 76    False  Program  42.004047 -87.817596  POINT (-87.817596436 42.004047394)
# 76    False  Program  42.004047 -87.817596  POINT (-87.817596436 42.004047394)
# 76    False  Program  42.004047 -87.817596  POINT (-87.817596436 42.004047394)
# 76    False  Program  42.004047 -87.817596  POINT (-87.817596436 42.004047394)
# 76    False  Program  42.004047 -87.817596  POINT (-87.817596436 42.004047394)
#
# [40272 rows x 41 columns]

# %%
ax = joined_data.plot(column='COMMUNITY',cmap='Blues', linewidth=0.5, edgecolor='0.8', figsize=(5,5))
ax.set_title('Activities by Neighborhood')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
plt.show()

# %%
chicago_final.loc[chicago_final['meeting_type'] == 'face_to_face'].transport_provided.value_counts()
# Out:
# False    39347
# True        53
# Name: transport_provided, dtype: int64

# %%
inperson = chicago_final.loc[chicago_final['meeting_type'] == 'face_to_face']
inperson_notransport = inperson.loc[inperson['transport_provided'] == False]

# %%
inperson_notransport['GEOG'].value_counts()
# Out:
# Irving Park           2439
# Near West Side        1713
# Morgan Park           1488
# West Garfield Park    1016
# Logan Square           959
#                       ...
# Montclare              158
# Hyde Park              135
# Avalon Park            128
# Fuller Park            107
# Calumet Heights         28
# Name: GEOG, Length: 75, dtype: int64

# %%
count = inperson_notransport['GEOG'].value_counts()

count_transport = pd.DataFrame({'GEOG': count.index, 'count': count.values})

# Merge the count data with the original GeoDataFrame
merged_transport = inperson_notransport.merge(count_transport, on='GEOG')

# Plot the count on the map
fig, ax = plt.subplots(figsize=(5, 5))
chicago_map.plot(ax=ax, color='white', linewidth=0.5, edgecolor='0.8')
merged_transport.plot(column='count', cmap='Blues', linewidth=0.5, edgecolor='0.8', legend=True, ax=ax)
plt.title("Face-to-Face opportunities \nthat do not provide transport")

plt.show()

# %%
ax = inperson_nottransport.plot(column='COMMUNITY',cmap='Blues', linewidth=0.5, edgecolor='0.8', figsize=(5,5))
ax.set_title('Activities by Neighborhood')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
plt.show()

# %% [markdown]
# #### Activities by Category

# %%
for group, data in chicago_final.groupby('category_name'):
    count = data['GEOG'].value_counts()
    
    count_df = pd.DataFrame({'GEOG': count.index, 'count': count.values})
    
    # Merge the count data with the original GeoDataFrame
    merged_gdf = chicago_final.merge(count_df, on='GEOG')
    
    # Plot the count on the map
    fig, ax = plt.subplots(figsize=(5, 5))
    chicago_map.plot(ax=ax, color='white', linewidth=0.5, edgecolor='0.8')
    merged_gdf.plot(column='count', cmap='Blues', linewidth=0.5, edgecolor='0.8', legend=True, ax=ax)
    plt.title(group)
    
    plt.show()

# %%
for group, data in joined_data.groupby('category_name'):
    # Plot the group with a different color and marker size
    fig, ax = plt.subplots(figsize=(5,5))
    chicago_map.plot(ax=ax, color='white', linewidth=0.5, edgecolor='0.8')
    data.plot(ax=ax, cmap='Blues', markersize=50)
    plt.title(group)
    plt.show()

# %%
demographics = pd.read_csv('chicagodemographics.csv')

# %%
dem = demographics.drop([ '2000_POP', '2010_POP','A35_49','A50_64','A65_74','A75_84','OV85',
                  'RET_SALES','GEN_MERCH','RES_EAV','CMRCL_EAV','IND_EAV','RAIL_EAV','FARM_EAV','MIN_EAV','TOT_EAV',
                  '2000_UND19','2000_A20_34','2000_A35_49','2000_A50_64','2000_OV65','2000_MED_AGE','2000_TOT_HH','2000_OWN_OCC_HU','2000_RENT_OCC_HU','2000_VAC_HU','2000_HU_TOT','2000_LT_HS','2000_HS','2000_SOME_COLL','2000_ASSOC','2000_BACH','2000_GRAD_PROF','2000_POP_25OV','HT_Cost_Typical','HT_Cost_Mod','H_Cost_Typical','H_Cost_Mod','T_Cost_Typical','T_Cost_Mod'], axis =1)

# %%
from fuzzywuzzy import fuzz, process

def match_column(row, column, options):
    best_match = process.extractOne(row[column], options)
    return best_match[0]

chicagogeo['GEOG'] = chicagogeo.apply(match_column, args=('COMMUNITY', dem['GEOG']), axis=1)

joined = pd.merge(chicagogeo, dem, on='GEOG')

# %%
joined.head(1)
# Out:
#                                             the_geom  PERIMETER  AREA  \
# 0  MULTIPOLYGON (((-87.60914087617894 41.84469250...          0     0
#
#    COMAREA_  COMAREA_ID  AREA_NUMBE COMMUNITY  AREA_NUM_1    SHAPE_AREA  \
# 0         0           0          35   DOUGLAS          35  4.600462e+07
#
#      SHAPE_LEN  ... assoc_plus_pct in_lbr_frc_pct  \
# 0  31027.05451  ...       0.493141        0.67275
#
#    pct_pop_access_4_acres_per_1k  pct_pop_access_10_acres_per_1k  \
# 0                            1.0                        0.125617
#
#    impervious_acres_per_hh  modhigh_ta_pop_pct  modhigh_ta_emp_pct  \
# 0                 0.072544                 1.0                 1.0
#
#    nonsov_pct  unemployment_rate   pct_poc
# 0    0.558103           0.137737  0.894172
#
# [1 rows x 231 columns]

# %%
chicago_dem_cleaned = joined.drop(['PERIMETER','AREA','COMAREA_','COMAREA_ID','HU_TOT','HU_SNG_DET','HU_SNG_ATT',
                                   'HU_2UN','HU_3_4UN','HU_5_9UN','HU_10_19UN','HU_GT_19UN','HU_MOBILE','MED_ROOMS',
                                   'HA_AFT2000','HA_70_00','HA_40_70','HA_BEF1940','MED_HA','BR_0_1','BR_2','BR_3',
                                   'BR_4','BR_5','WORK_NAICS1_TYPE','WORK_NAICS2_TYPE','WORK_NAICS3_TYPE',
                                   'WORK_NAICS4_TYPE','WORK_NAICS5_TYPE','WORK_NAICS1_COUNT','WORK_NAICS2_COUNT',
                                   'WORK_NAICS3_COUNT','WORK_NAICS4_COUNT','WORK_NAICS5_COUNT','RES_CITY1_TYPE',
                                   'RES_CITY2_TYPE','RES_CITY3_TYPE','RES_CITY4_TYPE','RES_CITY5_TYPE','RES_CITY1_COUNT',
                                   'RES_CITY2_COUNT','RES_CITY3_COUNT','RES_CITY4_COUNT','RES_CITY5_COUNT','WORK_CITY1_TYPE',
                                   'WORK_CITY2_TYPE','WORK_CITY3_TYPE','WORK_CITY4_TYPE','WORK_CITY5_TYPE','WORK_CITY1_COUNT',
                                   'WORK_CITY2_COUNT','WORK_CITY3_COUNT','WORK_CITY4_COUNT','WORK_CITY5_COUNT','IDES_START_EMP',
                                   'IDES_MID_EMP','IDES_CURR_EMP','AVG_VMT'],axis=1)

# %%
chicago_dem_cleaned.head(1)
# Out:
#                                             the_geom  AREA_NUMBE COMMUNITY  \
# 0  MULTIPOLYGON (((-87.60914087617894 41.84469250...          35   DOUGLAS
#
#    AREA_NUM_1    SHAPE_AREA    SHAPE_LEN  \
# 0          35  4.600462e+07  31027.05451
#
#                                             geometry     GEOG  GEOID  \
# 0  MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...  Douglas     35
#
#    2020_POP  ...  assoc_plus_pct  in_lbr_frc_pct  \
# 0     20291  ...        0.493141         0.67275
#
#    pct_pop_access_4_acres_per_1k  pct_pop_access_10_acres_per_1k  \
# 0                            1.0                        0.125617
#
#    impervious_acres_per_hh  modhigh_ta_pop_pct  modhigh_ta_emp_pct  \
# 0                 0.072544                 1.0                 1.0
#
#    nonsov_pct  unemployment_rate   pct_poc
# 0    0.558103           0.137737  0.894172
#
# [1 rows x 173 columns]

# %%
chicago_merged = pd.merge(chicago_dem_cleaned, mcmf_geo, on=['the_geom', 'AREA_NUMBE', 'COMMUNITY',
                                                             'AREA_NUM_1','SHAPE_AREA','SHAPE_LEN',
                                                             'geometry','GEOG'],how='right')

# %%
chicago_merged = chicago_merged.drop(['the_geom','AREA_NUMBE','COMMUNITY','AREA_NUM_1'],axis=1)

# %%
chicago_final.head(1)
# Out:
#      SHAPE_AREA    SHAPE_LEN  \
# 0  4.600462e+07  31027.05451
#
#                                             geometry     GEOG  GEOID  \
# 0  MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...  Douglas     35
#
#    2020_POP  2020_HH  2020_HH_SIZE  TOT_POP   A5_19  ...  \
# 0     20291     9878      1.871229  21450.0  3500.0  ...
#
#    scholarship_available  participants_paid  transport_provided  \
# 0                  False           Not Paid               False
#
#    has_free_food  meeting_type  featured      tag   latitude  longitude  \
# 0           True  face_to_face     False  Program  41.826199 -87.621597
#
#                             location
# 0  POINT (-87.62159729 41.826198578)
#
# [1 rows x 67 columns]

# %%
chicago_final.columns.tolist()
# Out:
# ['SHAPE_AREA',
#  'SHAPE_LEN',
#  'geometry',
#  'GEOG',
#  'GEOID',
#  '2020_POP',
#  '2020_HH',
#  '2020_HH_SIZE',
#  'TOT_POP',
#  'A5_19',
#  'A20_34',
#  'MED_AGE',
#  'WHITE',
#  'HISP',
#  'BLACK',
#  'ASIAN',
#  'OTHER',
#  'IN_LBFRC',
#  'EMP',
#  'UNEMP',
#  'NOT_IN_LBFRC',
#  'MEDINC',
#  'INCPERCAP',
#  'MED_HV',
#  'MED_RENT',
#  'INTERNET',
#  'NO_INTERNET',
#  'TRANSIT_LOW_PCT',
#  'TRANSIT_MOD_PCT',
#  'TRANSIT_HIGH_PCT',
#  'WALKABLE_LOW_PCT',
#  'WALKABLE_MOD_PCT',
#  'WALKABLE_HIGH_PCT',
#  'highly_walkable_pop_pct',
#  'highly_walkable_emp_pct',
#  'in_lbr_frc_pct',
#  'modhigh_ta_pop_pct',
#  'modhigh_ta_emp_pct',
#  'unemployment_rate',
#  'pct_poc',
#  'program_id',
#  'program_name',
#  'description',
#  'org_name',
#  'category_name',
#  'capacity',
#  'min_age',
#  'max_age',
#  'address',
#  'city',
#  'state',
#  'zip_code',
#  'program_type',
#  'start_date',
#  'end_date',
#  'program_price',
#  'geographic_cluster_name',
#  'scholarship_available',
#  'participants_paid',
#  'transport_provided',
#  'has_free_food',
#  'meeting_type',
#  'featured',
#  'tag',
#  'latitude',
#  'longitude',
#  'location']

# %%
chicago_final.shape
# Out:
# (40272, 63)

# %%
chicago_final = chicago_merged.drop(['RES_NAICS1_TYPE','RES_NAICS2_TYPE','RES_NAICS3_TYPE','RES_NAICS4_TYPE',
                                     'RES_NAICS5_TYPE','RES_NAICS1_COUNT','RES_NAICS2_COUNT','RES_NAICS3_COUNT',
                                     'RES_NAICS4_COUNT','RES_NAICS5_COUNT','TOT_ACRES','SF','Sfperc','MF','Mfperc',
                                     'MIX','MIXperc','COMM','COMMperc','INST','INSTperc','IND','INDperc','TRANS',
                                     'TRANSperc','AG','Agperc','OPEN','OPENperc','VACANT','VACperc','CT_1PHH',
                                     'CT_2PHH','CT_3PHH','CT_4MPHH','CT_FAM_HH','CT_SP_WCHILD','CT_NONFAM_HH',
                                     'HCUND20K','HCUND20K_LT20PCT','HCUND20K_20_29PCT','HCUND20K_30MPCT','HC20Kto49K',
                                     'HC20Kto49K_LT20PCT','HC20Kto49K_20_29PCT','HC20Kto49K_30MPCT','HC50Kto75K',
                                     'HC50Kto75K_LT20PCT','HC50Kto75K_20_29PCT','HC50Kto75K_30MPCT','HCOV75K',
                                     'HCOV75K_LT20PCT','HCOV75K_20_29PCT','HCOV75K_30MPCT','RENT_LT500',
                                     'RENT_500_999','RENT_1000_1499','RENT_1500_2499','RENT_GT2500','TOT_HH',
                                     'OWN_OCC_HU','RENT_OCC_HU','VAC_HU','HV_LT_150K','HV_150_300K','HV_300_500K',
                                     'HV_GT_500K','pct_pop_access_4_acres_per_1k','pct_pop_access_10_acres_per_1k',
                                     'AGG_TT','CASHRENT_HH','TOT_EMP_RES','TOT_EMP_WORK','OPEN_SPACE_PER_1000',
                                     'NOT_ENGLISH','LING_ISO','ENGLISH','SPANISH','SLAVIC','CHINESE','TAGALOG',
                                     'ARABIC','KOREAN','OTHER_ASIAN','OTHER_EURO','OTHER_UNSPEC','index_right',
                                     'WORK_AT_HOME','TOT_COMM','DROVE_AL','CARPOOL','TRANSIT','WALK_BIKE','COMM_OTHER',
                                     'INC_LT_25K','INC_25_50K','INC_50_75K','INC_75_100K','INC_100_150K','INC_GT_150',
                                     '2000_WHITE','2000_HISP','2000_BLACK','2000_ASIAN','2000_OTHER','TOT_WRKR16OV',
                                     'NO_VEH','ONE_VEH','TWO_VEH','THREEOM_VEH','COMPUTER','ONLY_SMARTPHONE',
                                     'NO_COMPUTER','BROADBAND','LT_HS','HS','SOME_COLL','ASSOC','BACH','GRAD_PROF',
                                     'NATIVE','FOR_BORN','POP_OV5','impervious_acres_per_hh','assoc_plus_pct','UND5',
                                     'GEOID','2020_POP','2020_HH','2020_HH_SIZE',
                                     'POP_HH','POP_16OV','POP_25OV','registration_deadline',
                                     'nonsov_pct','contact_name','contact_phone','contact_email','hidden_programs',
                                     'program_url','online_address','registration_url','registration_open',
                                     'image','start_time','end_time'],axis=1)

# %%
chicago_final.to_csv('chicago_final.csv.gz', compression='gzip',index=False)

# %% [markdown]
# #### Walkability/Transit

# %%
ax = joined.plot(column='TRANSIT_LOW_PCT', cmap='Blues', linewidth=0.5, edgecolor='0.8', legend=True)

# Set plot title and axis labels
ax.set_title('Population with low transit availability')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

legend = ax.get_legend()
plt.show()

# %%
ax = joined.plot(column='TRANSIT_LOW_PCT', cmap='Blues', linewidth=0.5, edgecolor='0.8', legend=True)

# Set plot title and axis labels
ax.set_title('Population with low transit availability')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

legend = ax.get_legend()
plt.show()

# %% [markdown]
# #### Unemployment Rate

# %%
joined['unemployment_rate'] = joined['UNEMP'] / joined['IN_LBFRC']

# %%
ax = joined.plot(column='unemployment_rate', cmap='Blues', linewidth=0.8, edgecolor='0.8', legend=True)

# Set plot title and axis labels
ax.set_title('Unemployment Rate by Neighborhood')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

legend = ax.get_legend()
plt.show()

# %% [markdown]
# #### % POC by Neighborhood

# %%
joined['pct_poc'] = (joined['HISP'] + joined['BLACK'] + joined['ASIAN'] + joined['OTHER']) / (joined['WHITE'] + joined['HISP'] + joined['BLACK'] + joined['ASIAN'] + joined['OTHER'])

# %%
ax = joined.plot(column='pct_poc', cmap='Blues', linewidth=0.5, edgecolor='0.8', legend=True)

# Set plot title and axis labels
ax.set_title('Percentage of POC by Neighborhood')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

legend = ax.get_legend()
plt.show()

# %% [markdown]
# #### Access to Internet by Neighborhood

# %%
chicago_final.columns
# Out:
# Index(['SHAPE_AREA', 'SHAPE_LEN', 'geometry', 'GEOG', 'TOT_POP', 'A5_19',
#        'A20_34', 'MED_AGE', 'WHITE', 'HISP', 'BLACK', 'ASIAN', 'OTHER',
#        'IN_LBFRC', 'EMP', 'UNEMP', 'NOT_IN_LBFRC', 'MEDINC', 'INCPERCAP',
#        'MED_HV', 'MED_RENT', 'INTERNET', 'NO_INTERNET', 'TRANSIT_LOW_PCT',
#        'TRANSIT_MOD_PCT', 'TRANSIT_HIGH_PCT', 'WALKABLE_LOW_PCT',
#        'WALKABLE_MOD_PCT', 'WALKABLE_HIGH_PCT', 'highly_walkable_pop_pct',
#        'highly_walkable_emp_pct', 'in_lbr_frc_pct', 'modhigh_ta_pop_pct',
#        'modhigh_ta_emp_pct', 'unemployment_rate', 'pct_poc', 'program_id',
#        'program_name', 'description', 'org_name', 'category_name', 'capacity',
#        'min_age', 'max_age', 'address', 'city', 'state', 'zip_code',
#        'program_type', 'start_date', 'end_date', 'program_price',
#        'geographic_cluster_name', 'scholarship_available', 'participants_paid',
#        'transport_provided', 'has_free_food', 'meeting_type', 'featured',
#        'tag', 'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
ax = joined.plot(column='NO_INTERNET', cmap='Blues', linewidth=0.8, edgecolor='0.8', legend=True)

# Set plot title and axis labels
ax.set_title('Households with No Internet by Neighborhood')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

legend = ax.get_legend()
plt.show()

# %% [markdown]
# #### Median Income by Neighborhood

# %%
ax = joined.plot(column='MEDINC', cmap='Blues', linewidth=0.8, edgecolor='0.8', legend=True)

# Set plot title and axis labels
ax.set_title('Median Income by Neighborhood')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

legend = ax.get_legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

joined.plot(ax=ax, color='white', edgecolor='lightgrey')

for idx, row in joined.iterrows():
    if row['geometry'] is not None:
        centroid = row['geometry'].centroid.coords[0]
        ax.annotate(text=row['GEOG'], xy=centroid, color='black', fontsize=4, ha='center')

# Set plot title and axis labels
ax.set_title('Map with Neighborhood Labels')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Show the plot
plt.show()

# %% [markdown]
# ### Meeting Types

# %%
# Count based on meeting types
sns.countplot(x='meeting_type', data=df,palette='Blues')
plt.show()

# %% [markdown]
# ### Top Categories

# %%
df_young['category_name'].value_counts().head(5)
# Out:
# Sports + Wellness.    22529
# Music & Art.          11388
# Reading & Writing.     5145
# Academic Support       1593
# Science                 841
# Name: category_name, dtype: int64

# %%
# Create a new DataFrame from the top 5 values
df_top_5 = pd.DataFrame({'column_name': df_young['category_name'].value_counts().head(5).index, 'count': df_young['category_name'].value_counts().head(5).values})

# %%
# Count based on category name
sns.set_style("darkgrid")
plt.figure(figsize=(10, 5))
sns.barplot(x='column_name', y = 'count', data = df_top_5)
plt.xlabel('Categories')
plt.ylabel('Number of Programs')
plt.title('Top Five Program Categories for Youth')
plt.show()

# %% [markdown]
# ## Binning Data

# %%
df_young['age_binned'] = pd.qcut(df_young['max_age'], q=5, labels=['(0-5]', '(5-10]', '(10-15]', '(15-20]', '(20-24]'])
# Out:
# /var/folders/8n/jcf8jkgd07q33yx5hgq1969r0000gn/T/ipykernel_93018/1598739233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_young['age_binned'] = pd.qcut(df_young['max_age'], q=5, labels=['(0-5]', '(5-10]', '(10-15]', '(15-20]', '(20-24]'])

# %%
age_count = df_young['age_binned'].value_counts()
plt.figure(figsize=(10, 5))

age_count.plot(kind='bar', color=sns.color_palette('Blues', len(age_count)))
plt.xlabel('Age')
plt.ylabel('No. of Programs')
plt.title('No. of Programs Available per Age Group')
# Out:
# Text(0.5, 1.0, 'No. of Programs Available per Age Group')

# %% [markdown]
# ### Top Categories per Age Group

# %%
# Creating separate dataframes per age group 
df_0_5 = df_young.loc[df_young['age_binned'] == '(0-5]'] 
df_5_10 = df_young.loc[df_young['age_binned'] == '(5-10]'] 
df_10_15 = df_young.loc[df_young['age_binned'] == '(10-15]'] 
df_15_20 = df_young.loc[df_young['age_binned'] == '(15-20]'] 
df_20_24 = df_young.loc[df_young['age_binned'] == '(20-24]']

# %%
# 0 to 5
top_0_5 = pd.DataFrame({'column_name': df_0_5['category_name'].value_counts().head(5).index, 
                         'count': df_0_5['category_name'].value_counts().head(5).values})
# Count based on category name
sns.set_style("darkgrid")
plt.figure(figsize=(10, 5))
sns.barplot(x='column_name', y = 'count', data = top_0_5, palette = 'Blues')

plt.xlabel('Categories')
plt.ylabel('Number of Programs')
plt.title('Top Five Program Categories for Maximum Age 0-5')
plt.show()

# %%
# 5 to 10
top_5_10 = pd.DataFrame({'column_name': df_5_10['category_name'].value_counts().head(5).index, 
                         'count': df_5_10['category_name'].value_counts().head(5).values})
# Count based on category name
sns.set_style("darkgrid")
plt.figure(figsize=(10, 5))
sns.barplot(x='column_name', y = 'count', data = top_5_10, palette = 'Blues')
plt.xlabel('Categories')
plt.ylabel('Number of Programs')
plt.title('Top Five Program Categories for Maximum Age 5-10')
plt.show()

# %%
# 10 to 15
top_10_15 = pd.DataFrame({'column_name': df_10_15['category_name'].value_counts().head(5).index, 
                         'count': df_10_15['category_name'].value_counts().head(5).values})
# Count based on category name
sns.set_style("darkgrid")
plt.figure(figsize=(10, 5))
sns.barplot(x='column_name', y = 'count', data = top_10_15, palette = 'Blues')
plt.xlabel('Categories')
plt.ylabel('Number of Programs')
plt.title('Top Five Program Categories for Maximum Age 10-15')
plt.show()

# %%
# 5 to 10
top_15_20 = pd.DataFrame({'column_name': df_15_20['category_name'].value_counts().head(5).index, 
                         'count': df_15_20['category_name'].value_counts().head(5).values})
# Count based on category name
sns.set_style("darkgrid")
plt.figure(figsize=(10, 5))
sns.barplot(x='column_name', y = 'count', data = top_15_20, palette = 'Blues')
plt.xlabel('Categories')
plt.ylabel('Number of Programs')
plt.title('Top Five Program Categories for Maximum Age 15-20')
plt.show()

# %%
# 20 to 24
top_20_24 = pd.DataFrame({'column_name': df_20_24['category_name'].value_counts().head(5).index, 
                         'count': df_20_24['category_name'].value_counts().head(5).values})
# Count based on category name
sns.set_style("darkgrid")
plt.figure(figsize=(10, 5))
sns.barplot(x='column_name', y = 'count', data = top_20_24, palette = 'Blues')
plt.xlabel('Categories')
plt.ylabel('Number of Programs')
plt.title('Top Five Program Categories for Maximum Age 20-24')
plt.show()

# %%
df_young.program_price.value_counts()
# Out:
# Free             20963
# $50 or Less      15949
# More Than $50     5679
# Unknown           2239
# Name: program_price, dtype: int64

# %%
program_price_grouped = df_young.groupby([ 'category_name', 'program_price'], dropna = False)

# %%
program_price_counts = program_price_grouped.size().reset_index(name='count')

# %%
plt.pie(program_price_counts['count'].loc[program_price_counts['category_name'] == 'Academic Support'], 
        labels=['$50 or Less', 'More Than $50', 'Unknown'])
plt.title('Academic Support')
plt.show()

# %%
categories = program_price_counts['category_name'].unique()
program_price_counts['program_price'].loc[program_price_counts['category_name'] == 'Building & Fixing Things'].tolist()
# Out:
# ['$50 or Less', 'Free', 'More Than $50', 'Unknown']

# %%
categories = program_price_counts['category_name'].unique()
categories
# Out:
# array(['Academic Support', 'Building & Fixing Things', 'Computers.',
#        'Customer/Human Service', 'Digital Media.', 'Food.', 'Healthcare',
#        'Helping Your Community.', 'Law', 'Managing Money.', 'Math',
#        'Music & Art.', 'Nature.', 'Performance.', 'Reading & Writing.',
#        'Science', 'Science & Math', 'Social Studies',
#        'Sports + Wellness.', 'Teaching', 'Transportation',
#        'Work + Career', nan], dtype=object)

# %%
categories = program_price_counts['category_name'].unique()
for cat in categories:
    # Get the data for the current category    
    # Create a pie chart
    colors = sns.color_palette('pastel')
    plt.pie(program_price_counts['count'].loc[program_price_counts['category_name'] == cat], 
            labels=program_price_counts['program_price'].loc[program_price_counts['category_name'] == cat].tolist(),
            )
    plt.title(f'{cat}')
    plt.show()

# %%
df_young.to_csv('MCMF Young.csv', index=False)
